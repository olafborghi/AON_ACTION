# %% [markdown]
# # Convert DICOM images to niftys in BIDS structure
#
# ### Author: Olaf Borghi
#
# Parts of this notebook are coded in Python, other parts in Bash. Bash code is indicated by %%bash at the beginning of a cell.
# **Tutorial**: https://unfmontreal.github.io/Dcm2Bids/
#
# **System:** Ubuntu 22.04.1
#
# **Environment:** neuroenv (custom conda environment)
#
# **Dependencies of dcm2bids (installed in the conda environment)**:
# - dcm2niix (can be installed in a conda environment by conda install -c conda-forge dcm2niix)
# - dcm2bids (can be installed in a conda environment by conda install -c conda-forge dcm2bids)
# - python>=3.7
#
# **Other libraries installed**
# - jupyter lab (conda install -c conda-forge jupyterlab / conda install -c conda-forge nb_conda_kernels)
# - numpy, pip, pathlib, json,
# - Tree (sudo apt-get tree)

# %% [markdown]
# ## Setup

# %%
# import modules, make sure dependencies are installed in the environment
import os
import json
import dcm2bids
import numpy as np
from pathlib import Path

# %%
os.getcwd()
# Out:
# '/mnt/o/AON2bids'

# %%
# specify working directory in Python
work_dir=Path('/mnt/o/AON2bids')
# change to working directory to work_dir
os.chdir(work_dir)

# %%
# %%bash
# # create scaffold and store it in folder bids_scaffold
# dcm2bids_scaffold -o 03_bids_scaffold

# %%
# navigate to the scaffold folder
os.chdir(work_dir / "03_bids_scaffold")
os.getcwd()
# Out:
# '/mnt/o/AON2bids/03_bids_scaffold'

# %% [markdown]
# ### Import/locate/store the data
#
# You should either have the data available on your local machine already in a folder, or download the MRI data you would like to convert with !wget or similar tools. Make sure the data is also already unzipped, or unzip it before proceeding with the next steps.

# %% [markdown]
# ## Create the config file
#
# First, use the dcm2bids helper function to create a temporary folder were the dicoms are converted to niftys, so that you can read out information to create the config file.

# %%
# %%bash
# # lets take a look at the helper function
# dcm2bids_helper --help
# Out:
# usage: dcm2bids_helper [-h] -d DICOM_DIR [DICOM_DIR ...] [-o OUTPUT_DIR]
#                        [--force]
#
# helper module
#
# options:
#   -h, --help            show this help message and exit
#   -d DICOM_DIR [DICOM_DIR ...], --dicom_dir DICOM_DIR [DICOM_DIR ...]
#                         DICOM files directory.
#   -o OUTPUT_DIR, --output_dir OUTPUT_DIR
#                         Output BIDS directory. (Default: /mnt/o/AON2bids/03_bids_scaffold)
#   --force               Force command to overwrite existing output files.
#
# Documentation at https://github.com/unfmontreal/Dcm2Bids

# %%
# %%bash
# # specify the data directory
# data_dir='/mnt/o/AON2bids/01_data/mri/mri/'
#
# # run the helper function on sample data from one subject [in this case subject with the ID EV01]
# dcm2bids_helper -d ${data_dir}EV01
# Out:
# Example in: /mnt/o/AON2bids/03_bids_scaffold/tmp_dcm2bids/helper

# %% [markdown]
# **Data and exemplary task**
#
# A temporary folder containing information on your scans was made. In this folder, you can find a)converted nifty images for each acquisition and b).json files containing information for each acqusition.
#
# Note that a file was created for every file in the folder, but for now I am interested in the scans from an ACTION run, in which participants were instructed to move there hand when a hand-symbol was showing on the screen, and to move their mouth, when a mouth symbol was displayed. I am also interested in two runs of an Action Observation task, in which participants watched either 1) a dog or 2) a human performing a a) transitive or b) intransitive condition, as well as scrambled versions of these conditions.
#
# In addition I am interested in the T1 anatomical image and in the field map (one for all functional scans).
#
# You can open the JSON files from the temporary directory either directly in a new tab in Jupyter Lab or with any other text/code editor. Make sure to localize the correct file.

# %% [markdown]
# ### Populate a .json config file
#
# In this step, I create a .JSON config file in the bids_scaffold/code folder (you can also choose any other folder). I will do this within this notebook, but you can of course do this with every other code/text editor and don't need to do it in python. For a guide on how to work with .json files in Python, e.g. refer to https://pythonexamples.org/python-write-json-to-file/.
#
# We want to BIDSify the following data.
# - T1 anatomical image
# - ACTION run
# - AON run 1
# - AON run 2
# - Fielmap
#
# So first we have to find the corresponding files for each run/task/protocol in the temporary files that we created with the helper function in the folder \tmp_dcm2bids\helper.
#
# Please refer to these pages to see how to populate the config file:
#
# https://unfmontreal.github.io/Dcm2Bids/docs/how-to/create-config-file/
#
# https://unfmontreal.github.io/Dcm2Bids/docs/tutorial/first-steps/
#
# And for more general starting information on the BIDS format, refer to:
#
# https://bids-standard.github.io/bids-starter-kit/tutorials/annotation.html
#
# The config file basically has the structure of a dictonary and the information it contains should uniquely match the acquisition you target, in many cases the ```"SeriesDescription"``` in the temporary .json file will be a good indicator for the target acquisition.

# %%
# create the dictonary with the information from the temporary files
dcm2bids_dict = {
  "descriptions": [
    {
      "dataType": "anat",
      "modalityLabel": "T1w",
      "criteria": {
        "SeriesDescription": "t1_mprage_sag_p2_iso",
        "EchoTime": 0.00229
      },
      "sidecarChanges": {
        "ProtocolName": "t1_mprage_sag_p2_iso"
      }
    },
    {
      "dataType": "func",
      "modalityLabel": "bold",
      "customLabels": "task-action",
      "criteria": {
        "SeriesDescription": "ACTION_run_HR_222_tr1200_te34"
      },
      "sidecarChanges": {
        "TaskName": "action"
      }
    },
    {
      "dataType": "func",
      "modalityLabel": "bold",
      "customLabels": "task-AON_run-01",
      "criteria": {
        "SeriesDescription": "AONH_run1_HR_222_tr1200_te34"
      },
      "sidecarChanges": {
        "TaskName": "AON"
      }
    },
    {
      "dataType": "func",
      "modalityLabel": "bold",
      "customLabels": "task-AON_run-02",
      "criteria": {
        "SeriesDescription": "AONH_run2_HR_222_tr1200_te34"
      },
      "sidecarChanges": {
        "TaskName": "AON"
      }
    },
    {
      "dataType": "fmap",
      "modalityLabel": "phasediff",
      "criteria": {
        "SeriesDescription": "gre_field_mapping_bigFOV",
        "EchoTime1": 0.00492,
        "EchoTime2": 0.00738,
        "ImageType": ["ORIGINAL", "PRIMARY", "P", "ND", "PHASE"]
      },
      "IntendedFor": [1,2,3],
      "sidecarChanges": {
        "EchoTime1": 0.00492,
        "EchoTime2": 0.00738
        }
      },
    {
      "dataType": "fmap",
      "modalityLabel": "magnitude1",
      "criteria": {
        "SeriesDescription": "gre_field_mapping_bigFOV",
        "EchoNumber": 1,
        "EchoTime": 0.00492,
        "ImageType": ["ORIGINAL", "PRIMARY", "M", "ND", "NORM"]
      },
      "IntendedFor": [1,2,3],
      "sidecarChanges": {
        "EchoTime": 0.00492
        }
      },
    {
      "dataType": "fmap",
      "modalityLabel": "magnitude2",
      "criteria": {
        "SeriesDescription": "gre_field_mapping_bigFOV",
        "EchoNumber": 2,
        "EchoTime": 0.00738,
        "ImageType": ["ORIGINAL", "PRIMARY", "M", "ND", "NORM"]
      },
      "IntendedFor": [1,2,3],
      "sidecarChanges": {
        "EchoTime": 0.00738
        }
    }
  ]
}

# %%
# change directory to the code scaffold folder
os.chdir(work_dir / "03_bids_scaffold/code")

# %%
# create the json file from the dict and store it in the wd
jsonString = json.dumps(dcm2bids_dict,
                        sort_keys=True,
                        indent=4,
                        separators=(',', ': '))
jsonFile = open("dcm2bids_config.json", "w")
jsonFile.write(jsonString)
jsonFile.close()

# %%
# %%bash
# # see if the .json file is displayed correctly
# cat dcm2bids_config.json
# Out:
# {
#     "descriptions": [
#         {
#             "criteria": {
#                 "EchoTime": 0.00229,
#                 "SeriesDescription": "t1_mprage_sag_p2_iso"
#             },
#             "dataType": "anat",
#             "modalityLabel": "T1w",
#             "sidecarChanges": {
#                 "ProtocolName": "t1_mprage_sag_p2_iso"
#             }
#         },
#         {
#             "criteria": {
#                 "SeriesDescription": "ACTION_run_HR_222_tr1200_te34"
#             },
#             "customLabels": "task-action",
#             "dataType": "func",
#             "modalityLabel": "bold",
#             "sidecarChanges": {
#                 "TaskName": "action"
#             }
#         },
#         {
#             "criteria": {
#                 "SeriesDescription": "AONH_run1_HR_222_tr1200_te34"
#             },
#             "customLabels": "task-AON_run-01",
#             "dataType": "func",
#             "modalityLabel": "bold",
#             "sidecarChanges": {
#                 "TaskName": "AON"
#             }
#         },
#         {
#             "criteria": {
#                 "SeriesDescription": "AONH_run2_HR_222_tr1200_te34"
#             },
#             "customLabels": "task-AON_run-02",
#             "dataType": "func",
#             "modalityLabel": "bold",
#             "sidecarChanges": {
#                 "TaskName": "AON"
#             }
#         },
#         {
#             "IntendedFor": [
#                 1,
#                 2,
#                 3
#             ],
#             "criteria": {
#                 "EchoTime1": 0.00492,
#                 "EchoTime2": 0.00738,
#                 "ImageType": [
#                     "ORIGINAL",
#                     "PRIMARY",
#                     "P",
#                     "ND",
#                     "PHASE"
#                 ],
#                 "SeriesDescription": "gre_field_mapping_bigFOV"
#             },
#             "dataType": "fmap",
#             "modalityLabel": "phasediff",
#             "sidecarChanges": {
#                 "EchoTime1": 0.00492,
#                 "EchoTime2": 0.00738
#             }
#         },
#         {
#             "IntendedFor": [
#                 1,
#                 2,
#                 3
#             ],
#             "criteria": {
#                 "EchoNumber": 1,
#                 "EchoTime": 0.00492,
#                 "ImageType": [
#                     "ORIGINAL",
#                     "PRIMARY",
#                     "M",
#                     "ND",
#                     "NORM"
#                 ],
#                 "SeriesDescription": "gre_field_mapping_bigFOV"
#             },
#             "dataType": "fmap",
#             "modalityLabel": "magnitude1",
#             "sidecarChanges": {
#                 "EchoTime": 0.00492
#             }
#         },
#         {
#             "IntendedFor": [
#                 1,
#                 2,
#                 3
#             ],
#             "criteria": {
#                 "EchoNumber": 2,
#                 "EchoTime": 0.00738,
#                 "ImageType": [
#                     "ORIGINAL",
#                     "PRIMARY",
#                     "M",
#                     "ND",
#                     "NORM"
#                 ],
#                 "SeriesDescription": "gre_field_mapping_bigFOV"
#             },
#             "dataType": "fmap",
#             "modalityLabel": "magnitude2",
#             "sidecarChanges": {
#                 "EchoTime": 0.00738
#             }
#         }
#     ]
# }

# %% [markdown]
# **As soon as the config file is ready, we can delete the temporary files that we created with the helper function**

# %%
# %%bash
# tempdir='/mnt/o/AON2bids/03_bids_scaffold/tmp_dcm2bids'
# # delete temporary files
# rm -r ${tempdir}

# %% [markdown]
# ## Ready to go - run dcm2bids
#
# Bash code adapted from https://danieljwilson.com/science/2019/02/18/dicom-bids/
#
# Now we get to the easy part. Store/download/unzip the data in the bids_scaffold/sourcedata folder and you are good to run the following script.
# In my case, the folders were named EV01, EV02 .. EV40 for each subject. Therefore, I had to make a if-loop nested in a for loop to add a zero to the subject/foldername for subjects 1-9. This may not be necessary in your case.

# %%
# %%bash
# # let's quickly look at the help function
# dcm2bids --help
# Out:
# usage: dcm2bids [-h] -d DICOM_DIR [DICOM_DIR ...] -p PARTICIPANT [-s SESSION]
#                 -c CONFIG [-o OUTPUT_DIR] [--forceDcm2niix] [--clobber]
#                 [-l {DEBUG,INFO,WARNING,ERROR,CRITICAL}]
#
# Reorganising NIfTI files from dcm2niix into the Brain Imaging Data Structure
#
# options:
#   -h, --help            show this help message and exit
#   -d DICOM_DIR [DICOM_DIR ...], --dicom_dir DICOM_DIR [DICOM_DIR ...]
#                         DICOM directory(ies).
#   -p PARTICIPANT, --participant PARTICIPANT
#                         Participant ID.
#   -s SESSION, --session SESSION
#                         Session ID.
#   -c CONFIG, --config CONFIG
#                         JSON configuration file (see example/config.json).
#   -o OUTPUT_DIR, --output_dir OUTPUT_DIR
#                         Output BIDS directory. (Default: /mnt/o/AON2bids/03_bids_scaffold)
#   --forceDcm2niix       Overwrite previous temporary dcm2niix output if it exists.
#   --clobber             Overwrite output if it exists.
#   -l {DEBUG,INFO,WARNING,ERROR,CRITICAL}, --log_level {DEBUG,INFO,WARNING,ERROR,CRITICAL}
#                         Set logging level. [INFO]
#
# Documentation at https://github.com/unfmontreal/Dcm2Bids

# %%
# %%bash
#
# bidsdir='/mnt/o/AON2bids/03_bids_scaffold'
# mkdir ${bidsdir}/output
#
# # # convert dicoms to BIDS format dataset
# # # MULTIPLE SUBJECTS
# # # more general code if your sourcefolders are named 1,2,3 ... according to the subject id
# # for subject in {1,2}; do
# # 	dcm2bids \
# # 	    -d $bidsdir/sourcedata/${subject} \
# # 	    -p ${subject} \
# # 	    -c $bidsdir/code/dcm2bids_config.json \
# # 	    -o $bidsdir
# # done
#
# # convert dicoms to BIDS format dataset
# # MULTIPLE SUBJECTS
# # code if your folders are named differently, as in my case (EV01, EV02 .. EV40)
# for subject in {3,33}; do # quickly changed to try just for one sbj (for subject in {1:40}; do)
#     if [[ $subject -lt 9 ]]; then
#         dcm2bids \
#         -d /mnt/o/AON2bids/01_data/mri/mri/EV0${subject} \
#         -p 0${subject} \
#         -c $bidsdir/code/dcm2bids_config.json \
#         -o $bidsdir/output
#     elif [[ $subject -gt 9 ]]; then
#         dcm2bids \
#         -d /mnt/o/AON2bids/01_data/mri/mri/EV${subject} \
#         -p ${subject} \
#         -c $bidsdir/code/dcm2bids_config.json \
#         -o $bidsdir/output
#     fi
# done
# Out:
# mkdir: cannot create directory ‘/mnt/o/AON2bids/03_bids_scaffold/output’: File exists
# INFO:dcm2bids.dcm2bids:--- dcm2bids start ---
# INFO:dcm2bids.dcm2bids:OS:version: Linux-5.10.16.3-microsoft-standard-WSL2-x86_64-with-glibc2.35
# INFO:dcm2bids.dcm2bids:python:version: 3.11.0 | packaged by conda-forge | (main, Oct 25 2022, 06:24:40) [GCC 10.4.0]
# INFO:dcm2bids.dcm2bids:dcm2bids:version: 2.1.7
# INFO:dcm2bids.dcm2bids:dcm2niix:version: v1.0.20220720
# INFO:dcm2bids.dcm2bids:participant: sub-03
# INFO:dcm2bids.dcm2bids:session:
# INFO:dcm2bids.dcm2bids:config: /mnt/o/AON2bids/03_bids_scaffold/code/dcm2bids_config.json
# INFO:dcm2bids.dcm2bids:BIDS directory: /mnt/o/AON2bids/03_bids_scaffold/output
# WARNING:dcm2bids.version:Your using dcm2bids version 2.1.7
# WARNING:dcm2bids.version:A new version exists : 2.1.9
# WARNING:dcm2bids.version:Check https://github.com/unfmontreal/Dcm2Bids
# INFO:dcm2bids.utils:Running ['dcm2niix', '-b', 'y', '-ba', 'y', '-z', 'y', '-f', '%3s_%f_%p_%t', '-o', PosixPath('/mnt/o/AON2bids/03_bids_scaffold/output/tmp_dcm2bids/sub-03'), PosixPath('/mnt/o/AON2bids/01_data/mri/mri/EV03')]
# INFO:dcm2bids.dcm2niix:Check log file for dcm2niix output
# INFO:dcm2bids.sidecar:Sidecars pairing:
# INFO:dcm2bids.sidecar:No Pairing  <-  001_EV03_localizer_20200929123837_i00003
# INFO:dcm2bids.sidecar:No Pairing  <-  001_EV03_localizer_20200929123837_i00002
# INFO:dcm2bids.sidecar:No Pairing  <-  001_EV03_localizer_20200929123837_i00001
# INFO:dcm2bids.sidecar:No Pairing  <-  001_EV03_localizer_20200911150915_i00001
# INFO:dcm2bids.sidecar:No Pairing  <-  001_EV03_localizer_20200911150915_i00003
# INFO:dcm2bids.sidecar:No Pairing  <-  001_EV03_localizer_20200911150915_i00002
# INFO:dcm2bids.sidecar:No Pairing  <-  002_EV03_AAHead_Scout_32ch-head-coil_20200929123837
# INFO:dcm2bids.sidecar:No Pairing  <-  002_EV03_AAHead_Scout_32ch-head-coil_20200911150915
# INFO:dcm2bids.sidecar:No Pairing  <-  003_EV03_AAHead_Scout_32ch-head-coil_20200911150915_i00001
# INFO:dcm2bids.sidecar:No Pairing  <-  003_EV03_AAHead_Scout_32ch-head-coil_20200911150915_i00002
# INFO:dcm2bids.sidecar:No Pairing  <-  003_EV03_AAHead_Scout_32ch-head-coil_20200911150915_i00003
# INFO:dcm2bids.sidecar:No Pairing  <-  003_EV03_AAHead_Scout_32ch-head-coil_20200911150915_i00004
# INFO:dcm2bids.sidecar:No Pairing  <-  004_EV03_AAHead_Scout_32ch-head-coil_20200911150915_i00001
# INFO:dcm2bids.sidecar:No Pairing  <-  004_EV03_AAHead_Scout_32ch-head-coil_20200911150915_i00002
# INFO:dcm2bids.sidecar:No Pairing  <-  004_EV03_AAHead_Scout_32ch-head-coil_20200911150915_i00003
# INFO:dcm2bids.sidecar:No Pairing  <-  005_EV03_AAHead_Scout_32ch-head-coil_20200911150915_i00001
# INFO:dcm2bids.sidecar:No Pairing  <-  005_EV03_AAHead_Scout_32ch-head-coil_20200911150915_i00002
# INFO:dcm2bids.sidecar:No Pairing  <-  005_EV03_AAHead_Scout_32ch-head-coil_20200911150915_i00003
# INFO:dcm2bids.sidecar:No Pairing  <-  006_EV03_FoV_testscans_20200929123837
# INFO:dcm2bids.sidecar:No Pairing  <-  006_EV03_FoV_testscans_20200911150915
# INFO:dcm2bids.sidecar:No Pairing  <-  007_EV03_FOBH_run2_HR_222_tr1200_te34_20200911150915
# INFO:dcm2bids.sidecar:_task-AON_run-01_bold  <-  009_EV03_AONH_run1_HR_222_tr1200_te34_20200929123837
# INFO:dcm2bids.sidecar:No Pairing  <-  009_EV03_FOBH_run1_HR_222_tr1200_te34_20200911150915
# INFO:dcm2bids.sidecar:_task-AON_run-02_bold  <-  010_EV03_AONH_run2_HR_222_tr1200_te34_20200929123837
# INFO:dcm2bids.sidecar:_task-action_bold  <-  010_EV03_ACTION_run_HR_222_tr1200_te34_20200911150915
# INFO:dcm2bids.sidecar:_T1w  <-  011_EV03_t1_mprage_sag_p2_iso_20200911150915
# INFO:dcm2bids.sidecar:No Pairing  <-  012_EV03_rest_HR_222_tr1200_te34_20200929123837
# INFO:dcm2bids.sidecar:_magnitude1  <-  013_EV03_gre_field_mapping_bigFOV_20200929123837_e1
# INFO:dcm2bids.sidecar:_magnitude2  <-  013_EV03_gre_field_mapping_bigFOV_20200929123837_e2
# INFO:dcm2bids.sidecar:_phasediff  <-  014_EV03_gre_field_mapping_bigFOV_20200929123837_e2_ph
# INFO:dcm2bids.dcm2bids:moving acquisitions into BIDS folder
# INFO:dcm2bids.dcm2bids:--- dcm2bids start ---
# INFO:dcm2bids.dcm2bids:OS:version: Linux-5.10.16.3-microsoft-standard-WSL2-x86_64-with-glibc2.35
# INFO:dcm2bids.dcm2bids:python:version: 3.11.0 | packaged by conda-forge | (main, Oct 25 2022, 06:24:40) [GCC 10.4.0]
# INFO:dcm2bids.dcm2bids:dcm2bids:version: 2.1.7
# INFO:dcm2bids.dcm2bids:dcm2niix:version: v1.0.20220720
# INFO:dcm2bids.dcm2bids:participant: sub-33
# INFO:dcm2bids.dcm2bids:session:
# INFO:dcm2bids.dcm2bids:config: /mnt/o/AON2bids/03_bids_scaffold/code/dcm2bids_config.json
# INFO:dcm2bids.dcm2bids:BIDS directory: /mnt/o/AON2bids/03_bids_scaffold/output
# WARNING:dcm2bids.version:Your using dcm2bids version 2.1.7
# WARNING:dcm2bids.version:A new version exists : 2.1.9
# WARNING:dcm2bids.version:Check https://github.com/unfmontreal/Dcm2Bids
# INFO:dcm2bids.utils:Running ['dcm2niix', '-b', 'y', '-ba', 'y', '-z', 'y', '-f', '%3s_%f_%p_%t', '-o', PosixPath('/mnt/o/AON2bids/03_bids_scaffold/output/tmp_dcm2bids/sub-33'), PosixPath('/mnt/o/AON2bids/01_data/mri/mri/EV33')]
# INFO:dcm2bids.dcm2niix:Check log file for dcm2niix output
# INFO:dcm2bids.sidecar:Sidecars pairing:
# INFO:dcm2bids.sidecar:No Pairing  <-  001_EV33_localizer_20201118122335_i00003
# INFO:dcm2bids.sidecar:No Pairing  <-  001_EV33_localizer_20201118122335_i00002
# INFO:dcm2bids.sidecar:No Pairing  <-  001_EV33_localizer_20201118122335_i00001
# INFO:dcm2bids.sidecar:No Pairing  <-  002_EV33_AAHead_Scout_32ch-head-coil_20201118122335
# INFO:dcm2bids.sidecar:No Pairing  <-  003_EV33_AAHead_Scout_32ch-head-coil_20201118122335_i00001
# INFO:dcm2bids.sidecar:No Pairing  <-  003_EV33_AAHead_Scout_32ch-head-coil_20201118122335_i00002
# INFO:dcm2bids.sidecar:No Pairing  <-  003_EV33_AAHead_Scout_32ch-head-coil_20201118122335_i00003
# INFO:dcm2bids.sidecar:No Pairing  <-  003_EV33_AAHead_Scout_32ch-head-coil_20201118122335_i00004
# INFO:dcm2bids.sidecar:No Pairing  <-  004_EV33_AAHead_Scout_32ch-head-coil_20201118122335_i00001
# INFO:dcm2bids.sidecar:No Pairing  <-  004_EV33_AAHead_Scout_32ch-head-coil_20201118122335_i00002
# INFO:dcm2bids.sidecar:No Pairing  <-  004_EV33_AAHead_Scout_32ch-head-coil_20201118122335_i00003
# INFO:dcm2bids.sidecar:No Pairing  <-  005_EV33_AAHead_Scout_32ch-head-coil_20201118122335_i00001
# INFO:dcm2bids.sidecar:No Pairing  <-  005_EV33_AAHead_Scout_32ch-head-coil_20201118122335_i00002
# INFO:dcm2bids.sidecar:No Pairing  <-  005_EV33_AAHead_Scout_32ch-head-coil_20201118122335_i00003
# INFO:dcm2bids.sidecar:No Pairing  <-  006_EV33_FoV_testscans_20201118122335
# INFO:dcm2bids.sidecar:No Pairing  <-  007_EV33_FOBH_run1_HR_222_tr1200_te34_20201118122335
# INFO:dcm2bids.sidecar:No Pairing  <-  008_EV33_FOBH_run2_HR_222_tr1200_te34_20201118122335
# INFO:dcm2bids.sidecar:_task-AON_run-01_bold  <-  009_EV33_AONH_run1_HR_222_tr1200_te34_20201118122335
# INFO:dcm2bids.sidecar:_task-AON_run-02_bold  <-  010_EV33_AONH_run2_HR_222_tr1200_te34_20201118122335
# INFO:dcm2bids.sidecar:No Pairing  <-  011_EV33_localizer_20201118122335_i00001
# INFO:dcm2bids.sidecar:No Pairing  <-  011_EV33_localizer_20201118122335_i00003
# INFO:dcm2bids.sidecar:No Pairing  <-  011_EV33_localizer_20201118122335_i00002
# INFO:dcm2bids.sidecar:No Pairing  <-  012_EV33_AAHead_Scout_32ch-head-coil_20201118122335
# INFO:dcm2bids.sidecar:No Pairing  <-  013_EV33_AAHead_Scout_32ch-head-coil_20201118122335_i00001
# INFO:dcm2bids.sidecar:No Pairing  <-  013_EV33_AAHead_Scout_32ch-head-coil_20201118122335_i00002
# INFO:dcm2bids.sidecar:No Pairing  <-  013_EV33_AAHead_Scout_32ch-head-coil_20201118122335_i00003
# INFO:dcm2bids.sidecar:No Pairing  <-  013_EV33_AAHead_Scout_32ch-head-coil_20201118122335_i00004
# INFO:dcm2bids.sidecar:No Pairing  <-  014_EV33_AAHead_Scout_32ch-head-coil_20201118122335_i00001
# INFO:dcm2bids.sidecar:No Pairing  <-  014_EV33_AAHead_Scout_32ch-head-coil_20201118122335_i00002
# INFO:dcm2bids.sidecar:No Pairing  <-  014_EV33_AAHead_Scout_32ch-head-coil_20201118122335_i00003
# INFO:dcm2bids.sidecar:No Pairing  <-  015_EV33_AAHead_Scout_32ch-head-coil_20201118122335_i00001
# INFO:dcm2bids.sidecar:No Pairing  <-  015_EV33_AAHead_Scout_32ch-head-coil_20201118122335_i00002
# INFO:dcm2bids.sidecar:No Pairing  <-  015_EV33_AAHead_Scout_32ch-head-coil_20201118122335_i00003
# INFO:dcm2bids.sidecar:_task-action_bold  <-  017_EV33_ACTION_run_HR_222_tr1200_te34_20201118122335
# INFO:dcm2bids.sidecar:No Pairing  <-  018_EV33_WODO_run1_HR_222_tr1200_te34_20201118122335
# INFO:dcm2bids.sidecar:No Pairing  <-  019_EV33_WODO_run2_HR_222_tr1200_te34_20201118122335
# INFO:dcm2bids.sidecar:No Pairing  <-  020_EV33_rest_HR_222_tr1200_te34_20201118122335
# INFO:dcm2bids.sidecar:_magnitude1  <-  021_EV33_gre_field_mapping_bigFOV_20201118122335_e1
# INFO:dcm2bids.sidecar:_magnitude2  <-  021_EV33_gre_field_mapping_bigFOV_20201118122335_e2
# INFO:dcm2bids.sidecar:_phasediff  <-  022_EV33_gre_field_mapping_bigFOV_20201118122335_e2_ph
# INFO:dcm2bids.sidecar:_T1w  <-  023_EV33_t1_mprage_sag_p2_iso_20201118122335
# INFO:dcm2bids.dcm2bids:moving acquisitions into BIDS folder

# %% [markdown]
# ### Let's look at the output folder

# %%
# %%bash
# outputdir='/mnt/o/AON2bids/03_bids_scaffold/output/'
# # delete temporary files
# rm -r ${outputdir}tmp_dcm2bids
# # display our BIDS-structured folder
# tree $outputdir
# Out:
# /mnt/o/AON2bids/03_bids_scaffold/output/
# ├── sub-01
# │   ├── anat
# │   │   ├── sub-01_T1w.json
# │   │   └── sub-01_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-01_magnitude1.json
# │   │   ├── sub-01_magnitude1.nii.gz
# │   │   ├── sub-01_magnitude2.json
# │   │   ├── sub-01_magnitude2.nii.gz
# │   │   ├── sub-01_phasediff.json
# │   │   └── sub-01_phasediff.nii.gz
# │   └── func
# │       ├── sub-01_task-AON_run-01_bold.json
# │       ├── sub-01_task-AON_run-01_bold.nii.gz
# │       ├── sub-01_task-AON_run-02_bold.json
# │       ├── sub-01_task-AON_run-02_bold.nii.gz
# │       ├── sub-01_task-action_bold.json
# │       └── sub-01_task-action_bold.nii.gz
# ├── sub-02
# │   ├── anat
# │   │   ├── sub-02_T1w.json
# │   │   └── sub-02_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-02_magnitude1.json
# │   │   ├── sub-02_magnitude1.nii.gz
# │   │   ├── sub-02_magnitude2.json
# │   │   ├── sub-02_magnitude2.nii.gz
# │   │   ├── sub-02_phasediff.json
# │   │   └── sub-02_phasediff.nii.gz
# │   └── func
# │       ├── sub-02_task-AON_run-01_bold.json
# │       ├── sub-02_task-AON_run-01_bold.nii.gz
# │       ├── sub-02_task-AON_run-02_bold.json
# │       ├── sub-02_task-AON_run-02_bold.nii.gz
# │       ├── sub-02_task-action_bold.json
# │       └── sub-02_task-action_bold.nii.gz
# ├── sub-03
# │   ├── anat
# │   │   ├── sub-03_T1w.json
# │   │   └── sub-03_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-03_magnitude1.json
# │   │   ├── sub-03_magnitude1.nii.gz
# │   │   ├── sub-03_magnitude2.json
# │   │   ├── sub-03_magnitude2.nii.gz
# │   │   ├── sub-03_phasediff.json
# │   │   └── sub-03_phasediff.nii.gz
# │   └── func
# │       ├── sub-03_task-AON_run-01_bold.json
# │       ├── sub-03_task-AON_run-01_bold.nii.gz
# │       ├── sub-03_task-AON_run-02_bold.json
# │       ├── sub-03_task-AON_run-02_bold.nii.gz
# │       ├── sub-03_task-action_bold.json
# │       └── sub-03_task-action_bold.nii.gz
# ├── sub-04
# │   ├── anat
# │   │   ├── sub-04_T1w.json
# │   │   └── sub-04_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-04_magnitude1.json
# │   │   ├── sub-04_magnitude1.nii.gz
# │   │   ├── sub-04_magnitude2.json
# │   │   ├── sub-04_magnitude2.nii.gz
# │   │   ├── sub-04_phasediff.json
# │   │   └── sub-04_phasediff.nii.gz
# │   └── func
# │       ├── sub-04_task-AON_run-01_bold.json
# │       ├── sub-04_task-AON_run-01_bold.nii.gz
# │       ├── sub-04_task-AON_run-02_bold.json
# │       ├── sub-04_task-AON_run-02_bold.nii.gz
# │       ├── sub-04_task-action_bold.json
# │       └── sub-04_task-action_bold.nii.gz
# ├── sub-05
# │   ├── anat
# │   │   ├── sub-05_T1w.json
# │   │   └── sub-05_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-05_magnitude1.json
# │   │   ├── sub-05_magnitude1.nii.gz
# │   │   ├── sub-05_magnitude2.json
# │   │   ├── sub-05_magnitude2.nii.gz
# │   │   ├── sub-05_phasediff.json
# │   │   └── sub-05_phasediff.nii.gz
# │   └── func
# │       ├── sub-05_task-AON_run-01_bold.json
# │       ├── sub-05_task-AON_run-01_bold.nii.gz
# │       ├── sub-05_task-AON_run-02_bold.json
# │       ├── sub-05_task-AON_run-02_bold.nii.gz
# │       ├── sub-05_task-action_bold.json
# │       └── sub-05_task-action_bold.nii.gz
# ├── sub-06
# │   ├── anat
# │   │   ├── sub-06_T1w.json
# │   │   └── sub-06_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-06_magnitude1.json
# │   │   ├── sub-06_magnitude1.nii.gz
# │   │   ├── sub-06_magnitude2.json
# │   │   ├── sub-06_magnitude2.nii.gz
# │   │   ├── sub-06_phasediff.json
# │   │   └── sub-06_phasediff.nii.gz
# │   └── func
# │       ├── sub-06_task-AON_run-01_bold.json
# │       ├── sub-06_task-AON_run-01_bold.nii.gz
# │       ├── sub-06_task-AON_run-02_bold.json
# │       ├── sub-06_task-AON_run-02_bold.nii.gz
# │       ├── sub-06_task-action_bold.json
# │       └── sub-06_task-action_bold.nii.gz
# ├── sub-07
# │   ├── anat
# │   │   ├── sub-07_T1w.json
# │   │   └── sub-07_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-07_magnitude1.json
# │   │   ├── sub-07_magnitude1.nii.gz
# │   │   ├── sub-07_magnitude2.json
# │   │   ├── sub-07_magnitude2.nii.gz
# │   │   ├── sub-07_phasediff.json
# │   │   └── sub-07_phasediff.nii.gz
# │   └── func
# │       ├── sub-07_task-AON_run-01_bold.json
# │       ├── sub-07_task-AON_run-01_bold.nii.gz
# │       ├── sub-07_task-AON_run-02_bold.json
# │       ├── sub-07_task-AON_run-02_bold.nii.gz
# │       ├── sub-07_task-action_bold.json
# │       └── sub-07_task-action_bold.nii.gz
# ├── sub-08
# │   ├── anat
# │   │   ├── sub-08_T1w.json
# │   │   └── sub-08_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-08_magnitude1.json
# │   │   ├── sub-08_magnitude1.nii.gz
# │   │   ├── sub-08_magnitude2.json
# │   │   ├── sub-08_magnitude2.nii.gz
# │   │   ├── sub-08_phasediff.json
# │   │   └── sub-08_phasediff.nii.gz
# │   └── func
# │       ├── sub-08_task-AON_run-01_bold.json
# │       ├── sub-08_task-AON_run-01_bold.nii.gz
# │       ├── sub-08_task-AON_run-02_bold.json
# │       ├── sub-08_task-AON_run-02_bold.nii.gz
# │       ├── sub-08_task-action_bold.json
# │       └── sub-08_task-action_bold.nii.gz
# ├── sub-09
# │   ├── anat
# │   │   ├── sub-09_T1w.json
# │   │   └── sub-09_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-09_magnitude1.json
# │   │   ├── sub-09_magnitude1.nii.gz
# │   │   ├── sub-09_magnitude2.json
# │   │   ├── sub-09_magnitude2.nii.gz
# │   │   ├── sub-09_phasediff.json
# │   │   └── sub-09_phasediff.nii.gz
# │   └── func
# │       ├── sub-09_task-AON_run-01_bold.json
# │       ├── sub-09_task-AON_run-01_bold.nii.gz
# │       ├── sub-09_task-AON_run-02_bold.json
# │       ├── sub-09_task-AON_run-02_bold.nii.gz
# │       ├── sub-09_task-action_bold.json
# │       └── sub-09_task-action_bold.nii.gz
# ├── sub-10
# │   ├── anat
# │   │   ├── sub-10_T1w.json
# │   │   └── sub-10_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-10_magnitude1.json
# │   │   ├── sub-10_magnitude1.nii.gz
# │   │   ├── sub-10_magnitude2.json
# │   │   ├── sub-10_magnitude2.nii.gz
# │   │   ├── sub-10_phasediff.json
# │   │   └── sub-10_phasediff.nii.gz
# │   └── func
# │       ├── sub-10_task-AON_run-01_bold.json
# │       ├── sub-10_task-AON_run-01_bold.nii.gz
# │       ├── sub-10_task-AON_run-02_bold.json
# │       ├── sub-10_task-AON_run-02_bold.nii.gz
# │       ├── sub-10_task-action_bold.json
# │       └── sub-10_task-action_bold.nii.gz
# ├── sub-11
# │   ├── anat
# │   │   ├── sub-11_T1w.json
# │   │   └── sub-11_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-11_magnitude1.json
# │   │   ├── sub-11_magnitude1.nii.gz
# │   │   ├── sub-11_magnitude2.json
# │   │   ├── sub-11_magnitude2.nii.gz
# │   │   ├── sub-11_phasediff.json
# │   │   └── sub-11_phasediff.nii.gz
# │   └── func
# │       ├── sub-11_task-AON_run-01_bold.json
# │       ├── sub-11_task-AON_run-01_bold.nii.gz
# │       ├── sub-11_task-AON_run-02_bold.json
# │       ├── sub-11_task-AON_run-02_bold.nii.gz
# │       ├── sub-11_task-action_bold.json
# │       └── sub-11_task-action_bold.nii.gz
# ├── sub-12
# │   ├── anat
# │   │   ├── sub-12_T1w.json
# │   │   └── sub-12_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-12_magnitude1.json
# │   │   ├── sub-12_magnitude1.nii.gz
# │   │   ├── sub-12_magnitude2.json
# │   │   ├── sub-12_magnitude2.nii.gz
# │   │   ├── sub-12_phasediff.json
# │   │   └── sub-12_phasediff.nii.gz
# │   └── func
# │       ├── sub-12_task-AON_run-01_bold.json
# │       ├── sub-12_task-AON_run-01_bold.nii.gz
# │       ├── sub-12_task-AON_run-02_bold.json
# │       ├── sub-12_task-AON_run-02_bold.nii.gz
# │       ├── sub-12_task-action_bold.json
# │       └── sub-12_task-action_bold.nii.gz
# ├── sub-13
# │   ├── anat
# │   │   ├── sub-13_T1w.json
# │   │   └── sub-13_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-13_magnitude1.json
# │   │   ├── sub-13_magnitude1.nii.gz
# │   │   ├── sub-13_magnitude2.json
# │   │   ├── sub-13_magnitude2.nii.gz
# │   │   ├── sub-13_phasediff.json
# │   │   └── sub-13_phasediff.nii.gz
# │   └── func
# │       ├── sub-13_task-AON_run-01_bold.json
# │       ├── sub-13_task-AON_run-01_bold.nii.gz
# │       ├── sub-13_task-AON_run-02_bold.json
# │       ├── sub-13_task-AON_run-02_bold.nii.gz
# │       ├── sub-13_task-action_bold.json
# │       └── sub-13_task-action_bold.nii.gz
# ├── sub-14
# │   ├── anat
# │   │   ├── sub-14_T1w.json
# │   │   └── sub-14_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-14_magnitude1.json
# │   │   ├── sub-14_magnitude1.nii.gz
# │   │   ├── sub-14_magnitude2.json
# │   │   ├── sub-14_magnitude2.nii.gz
# │   │   ├── sub-14_phasediff.json
# │   │   └── sub-14_phasediff.nii.gz
# │   └── func
# │       ├── sub-14_task-AON_run-01_bold.json
# │       ├── sub-14_task-AON_run-01_bold.nii.gz
# │       ├── sub-14_task-AON_run-02_bold.json
# │       ├── sub-14_task-AON_run-02_bold.nii.gz
# │       ├── sub-14_task-action_bold.json
# │       └── sub-14_task-action_bold.nii.gz
# ├── sub-15
# │   ├── anat
# │   │   ├── sub-15_T1w.json
# │   │   └── sub-15_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-15_magnitude1.json
# │   │   ├── sub-15_magnitude1.nii.gz
# │   │   ├── sub-15_magnitude2.json
# │   │   ├── sub-15_magnitude2.nii.gz
# │   │   ├── sub-15_phasediff.json
# │   │   └── sub-15_phasediff.nii.gz
# │   └── func
# │       ├── sub-15_task-AON_run-01_bold.json
# │       ├── sub-15_task-AON_run-01_bold.nii.gz
# │       ├── sub-15_task-AON_run-02_bold.json
# │       ├── sub-15_task-AON_run-02_bold.nii.gz
# │       ├── sub-15_task-action_bold.json
# │       └── sub-15_task-action_bold.nii.gz
# ├── sub-16
# │   ├── anat
# │   │   ├── sub-16_T1w.json
# │   │   └── sub-16_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-16_magnitude1.json
# │   │   ├── sub-16_magnitude1.nii.gz
# │   │   ├── sub-16_magnitude2.json
# │   │   ├── sub-16_magnitude2.nii.gz
# │   │   ├── sub-16_phasediff.json
# │   │   └── sub-16_phasediff.nii.gz
# │   └── func
# │       ├── sub-16_task-AON_run-01_bold.json
# │       ├── sub-16_task-AON_run-01_bold.nii.gz
# │       ├── sub-16_task-AON_run-02_bold.json
# │       ├── sub-16_task-AON_run-02_bold.nii.gz
# │       ├── sub-16_task-action_bold.json
# │       └── sub-16_task-action_bold.nii.gz
# ├── sub-17
# │   ├── anat
# │   │   ├── sub-17_T1w.json
# │   │   └── sub-17_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-17_magnitude1.json
# │   │   ├── sub-17_magnitude1.nii.gz
# │   │   ├── sub-17_magnitude2.json
# │   │   ├── sub-17_magnitude2.nii.gz
# │   │   ├── sub-17_phasediff.json
# │   │   └── sub-17_phasediff.nii.gz
# │   └── func
# │       ├── sub-17_task-AON_run-01_bold.json
# │       ├── sub-17_task-AON_run-01_bold.nii.gz
# │       ├── sub-17_task-AON_run-02_bold.json
# │       ├── sub-17_task-AON_run-02_bold.nii.gz
# │       ├── sub-17_task-action_bold.json
# │       └── sub-17_task-action_bold.nii.gz
# ├── sub-18
# │   ├── anat
# │   │   ├── sub-18_T1w.json
# │   │   └── sub-18_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-18_magnitude1.json
# │   │   ├── sub-18_magnitude1.nii.gz
# │   │   ├── sub-18_magnitude2.json
# │   │   ├── sub-18_magnitude2.nii.gz
# │   │   ├── sub-18_phasediff.json
# │   │   └── sub-18_phasediff.nii.gz
# │   └── func
# │       ├── sub-18_task-AON_run-01_bold.json
# │       ├── sub-18_task-AON_run-01_bold.nii.gz
# │       ├── sub-18_task-AON_run-02_bold.json
# │       ├── sub-18_task-AON_run-02_bold.nii.gz
# │       ├── sub-18_task-action_bold.json
# │       └── sub-18_task-action_bold.nii.gz
# ├── sub-19
# │   ├── anat
# │   │   ├── sub-19_T1w.json
# │   │   └── sub-19_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-19_magnitude1.json
# │   │   ├── sub-19_magnitude1.nii.gz
# │   │   ├── sub-19_magnitude2.json
# │   │   ├── sub-19_magnitude2.nii.gz
# │   │   ├── sub-19_phasediff.json
# │   │   └── sub-19_phasediff.nii.gz
# │   └── func
# │       ├── sub-19_task-AON_run-01_bold.json
# │       ├── sub-19_task-AON_run-01_bold.nii.gz
# │       ├── sub-19_task-AON_run-02_bold.json
# │       ├── sub-19_task-AON_run-02_bold.nii.gz
# │       ├── sub-19_task-action_bold.json
# │       └── sub-19_task-action_bold.nii.gz
# ├── sub-20
# │   ├── anat
# │   │   ├── sub-20_T1w.json
# │   │   └── sub-20_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-20_magnitude1.json
# │   │   ├── sub-20_magnitude1.nii.gz
# │   │   ├── sub-20_magnitude2.json
# │   │   ├── sub-20_magnitude2.nii.gz
# │   │   ├── sub-20_phasediff.json
# │   │   └── sub-20_phasediff.nii.gz
# │   └── func
# │       ├── sub-20_task-AON_run-01_bold.json
# │       ├── sub-20_task-AON_run-01_bold.nii.gz
# │       ├── sub-20_task-AON_run-02_bold.json
# │       ├── sub-20_task-AON_run-02_bold.nii.gz
# │       ├── sub-20_task-action_bold.json
# │       └── sub-20_task-action_bold.nii.gz
# ├── sub-21
# │   ├── anat
# │   │   ├── sub-21_T1w.json
# │   │   └── sub-21_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-21_magnitude1.json
# │   │   ├── sub-21_magnitude1.nii.gz
# │   │   ├── sub-21_magnitude2.json
# │   │   ├── sub-21_magnitude2.nii.gz
# │   │   ├── sub-21_phasediff.json
# │   │   └── sub-21_phasediff.nii.gz
# │   └── func
# │       ├── sub-21_task-AON_run-01_bold.json
# │       ├── sub-21_task-AON_run-01_bold.nii.gz
# │       ├── sub-21_task-AON_run-02_bold.json
# │       ├── sub-21_task-AON_run-02_bold.nii.gz
# │       ├── sub-21_task-action_bold.json
# │       └── sub-21_task-action_bold.nii.gz
# ├── sub-22
# │   ├── anat
# │   │   ├── sub-22_T1w.json
# │   │   └── sub-22_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-22_magnitude1.json
# │   │   ├── sub-22_magnitude1.nii.gz
# │   │   ├── sub-22_magnitude2.json
# │   │   ├── sub-22_magnitude2.nii.gz
# │   │   ├── sub-22_phasediff.json
# │   │   └── sub-22_phasediff.nii.gz
# │   └── func
# │       ├── sub-22_task-AON_run-01_bold.json
# │       ├── sub-22_task-AON_run-01_bold.nii.gz
# │       ├── sub-22_task-AON_run-02_bold.json
# │       ├── sub-22_task-AON_run-02_bold.nii.gz
# │       ├── sub-22_task-action_bold.json
# │       └── sub-22_task-action_bold.nii.gz
# ├── sub-23
# │   ├── anat
# │   │   ├── sub-23_T1w.json
# │   │   └── sub-23_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-23_magnitude1.json
# │   │   ├── sub-23_magnitude1.nii.gz
# │   │   ├── sub-23_magnitude2.json
# │   │   ├── sub-23_magnitude2.nii.gz
# │   │   ├── sub-23_phasediff.json
# │   │   └── sub-23_phasediff.nii.gz
# │   └── func
# │       ├── sub-23_task-AON_run-01_bold.json
# │       ├── sub-23_task-AON_run-01_bold.nii.gz
# │       ├── sub-23_task-AON_run-02_bold.json
# │       ├── sub-23_task-AON_run-02_bold.nii.gz
# │       ├── sub-23_task-action_bold.json
# │       └── sub-23_task-action_bold.nii.gz
# ├── sub-24
# │   ├── anat
# │   │   ├── sub-24_T1w.json
# │   │   └── sub-24_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-24_magnitude1.json
# │   │   ├── sub-24_magnitude1.nii.gz
# │   │   ├── sub-24_magnitude2.json
# │   │   ├── sub-24_magnitude2.nii.gz
# │   │   ├── sub-24_phasediff.json
# │   │   └── sub-24_phasediff.nii.gz
# │   └── func
# │       ├── sub-24_task-AON_run-01_bold.json
# │       ├── sub-24_task-AON_run-01_bold.nii.gz
# │       ├── sub-24_task-AON_run-02_bold.json
# │       ├── sub-24_task-AON_run-02_bold.nii.gz
# │       ├── sub-24_task-action_bold.json
# │       └── sub-24_task-action_bold.nii.gz
# ├── sub-25
# │   ├── anat
# │   │   ├── sub-25_T1w.json
# │   │   └── sub-25_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-25_magnitude1.json
# │   │   ├── sub-25_magnitude1.nii.gz
# │   │   ├── sub-25_magnitude2.json
# │   │   ├── sub-25_magnitude2.nii.gz
# │   │   ├── sub-25_phasediff.json
# │   │   └── sub-25_phasediff.nii.gz
# │   └── func
# │       ├── sub-25_task-AON_run-01_bold.json
# │       ├── sub-25_task-AON_run-01_bold.nii.gz
# │       ├── sub-25_task-AON_run-02_bold.json
# │       ├── sub-25_task-AON_run-02_bold.nii.gz
# │       ├── sub-25_task-action_bold.json
# │       └── sub-25_task-action_bold.nii.gz
# ├── sub-26
# │   ├── anat
# │   │   ├── sub-26_T1w.json
# │   │   └── sub-26_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-26_magnitude1.json
# │   │   ├── sub-26_magnitude1.nii.gz
# │   │   ├── sub-26_magnitude2.json
# │   │   ├── sub-26_magnitude2.nii.gz
# │   │   ├── sub-26_phasediff.json
# │   │   └── sub-26_phasediff.nii.gz
# │   └── func
# │       ├── sub-26_task-AON_run-01_bold.json
# │       ├── sub-26_task-AON_run-01_bold.nii.gz
# │       ├── sub-26_task-AON_run-02_bold.json
# │       ├── sub-26_task-AON_run-02_bold.nii.gz
# │       ├── sub-26_task-action_bold.json
# │       └── sub-26_task-action_bold.nii.gz
# ├── sub-27
# │   ├── anat
# │   │   ├── sub-27_T1w.json
# │   │   └── sub-27_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-27_magnitude1.json
# │   │   ├── sub-27_magnitude1.nii.gz
# │   │   ├── sub-27_magnitude2.json
# │   │   ├── sub-27_magnitude2.nii.gz
# │   │   ├── sub-27_phasediff.json
# │   │   └── sub-27_phasediff.nii.gz
# │   └── func
# │       ├── sub-27_task-AON_run-01_bold.json
# │       ├── sub-27_task-AON_run-01_bold.nii.gz
# │       ├── sub-27_task-AON_run-02_bold.json
# │       ├── sub-27_task-AON_run-02_bold.nii.gz
# │       ├── sub-27_task-action_bold.json
# │       └── sub-27_task-action_bold.nii.gz
# ├── sub-28
# │   ├── anat
# │   │   ├── sub-28_T1w.json
# │   │   └── sub-28_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-28_magnitude1.json
# │   │   ├── sub-28_magnitude1.nii.gz
# │   │   ├── sub-28_magnitude2.json
# │   │   ├── sub-28_magnitude2.nii.gz
# │   │   ├── sub-28_phasediff.json
# │   │   └── sub-28_phasediff.nii.gz
# │   └── func
# │       ├── sub-28_task-AON_run-01_bold.json
# │       ├── sub-28_task-AON_run-01_bold.nii.gz
# │       ├── sub-28_task-AON_run-02_bold.json
# │       ├── sub-28_task-AON_run-02_bold.nii.gz
# │       ├── sub-28_task-action_bold.json
# │       └── sub-28_task-action_bold.nii.gz
# ├── sub-29
# │   ├── anat
# │   │   ├── sub-29_T1w.json
# │   │   └── sub-29_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-29_magnitude1.json
# │   │   ├── sub-29_magnitude1.nii.gz
# │   │   ├── sub-29_magnitude2.json
# │   │   ├── sub-29_magnitude2.nii.gz
# │   │   ├── sub-29_phasediff.json
# │   │   └── sub-29_phasediff.nii.gz
# │   └── func
# │       ├── sub-29_task-AON_run-01_bold.json
# │       ├── sub-29_task-AON_run-01_bold.nii.gz
# │       ├── sub-29_task-AON_run-02_bold.json
# │       ├── sub-29_task-AON_run-02_bold.nii.gz
# │       ├── sub-29_task-action_bold.json
# │       └── sub-29_task-action_bold.nii.gz
# ├── sub-30
# │   ├── anat
# │   │   ├── sub-30_T1w.json
# │   │   └── sub-30_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-30_magnitude1.json
# │   │   ├── sub-30_magnitude1.nii.gz
# │   │   ├── sub-30_magnitude2.json
# │   │   ├── sub-30_magnitude2.nii.gz
# │   │   ├── sub-30_phasediff.json
# │   │   └── sub-30_phasediff.nii.gz
# │   └── func
# │       ├── sub-30_task-AON_run-01_bold.json
# │       ├── sub-30_task-AON_run-01_bold.nii.gz
# │       ├── sub-30_task-AON_run-02_bold.json
# │       ├── sub-30_task-AON_run-02_bold.nii.gz
# │       ├── sub-30_task-action_bold.json
# │       └── sub-30_task-action_bold.nii.gz
# ├── sub-31
# │   ├── anat
# │   │   ├── sub-31_T1w.json
# │   │   └── sub-31_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-31_magnitude1.json
# │   │   ├── sub-31_magnitude1.nii.gz
# │   │   ├── sub-31_magnitude2.json
# │   │   ├── sub-31_magnitude2.nii.gz
# │   │   ├── sub-31_phasediff.json
# │   │   └── sub-31_phasediff.nii.gz
# │   └── func
# │       ├── sub-31_task-AON_run-01_bold.json
# │       ├── sub-31_task-AON_run-01_bold.nii.gz
# │       ├── sub-31_task-AON_run-02_bold.json
# │       ├── sub-31_task-AON_run-02_bold.nii.gz
# │       ├── sub-31_task-action_bold.json
# │       └── sub-31_task-action_bold.nii.gz
# ├── sub-32
# │   ├── anat
# │   │   ├── sub-32_T1w.json
# │   │   └── sub-32_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-32_magnitude1.json
# │   │   ├── sub-32_magnitude1.nii.gz
# │   │   ├── sub-32_magnitude2.json
# │   │   ├── sub-32_magnitude2.nii.gz
# │   │   ├── sub-32_phasediff.json
# │   │   └── sub-32_phasediff.nii.gz
# │   └── func
# │       ├── sub-32_task-AON_run-01_bold.json
# │       ├── sub-32_task-AON_run-01_bold.nii.gz
# │       ├── sub-32_task-AON_run-02_bold.json
# │       ├── sub-32_task-AON_run-02_bold.nii.gz
# │       ├── sub-32_task-action_bold.json
# │       └── sub-32_task-action_bold.nii.gz
# ├── sub-33
# │   ├── anat
# │   │   ├── sub-33_T1w.json
# │   │   └── sub-33_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-33_magnitude1.json
# │   │   ├── sub-33_magnitude1.nii.gz
# │   │   ├── sub-33_magnitude2.json
# │   │   ├── sub-33_magnitude2.nii.gz
# │   │   ├── sub-33_phasediff.json
# │   │   └── sub-33_phasediff.nii.gz
# │   └── func
# │       ├── sub-33_task-AON_run-01_bold.json
# │       ├── sub-33_task-AON_run-01_bold.nii.gz
# │       ├── sub-33_task-AON_run-02_bold.json
# │       ├── sub-33_task-AON_run-02_bold.nii.gz
# │       ├── sub-33_task-action_bold.json
# │       └── sub-33_task-action_bold.nii.gz
# ├── sub-34
# │   ├── anat
# │   │   ├── sub-34_T1w.json
# │   │   └── sub-34_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-34_magnitude1.json
# │   │   ├── sub-34_magnitude1.nii.gz
# │   │   ├── sub-34_magnitude2.json
# │   │   ├── sub-34_magnitude2.nii.gz
# │   │   ├── sub-34_phasediff.json
# │   │   └── sub-34_phasediff.nii.gz
# │   └── func
# │       ├── sub-34_task-AON_run-01_bold.json
# │       ├── sub-34_task-AON_run-01_bold.nii.gz
# │       ├── sub-34_task-AON_run-02_bold.json
# │       ├── sub-34_task-AON_run-02_bold.nii.gz
# │       ├── sub-34_task-action_bold.json
# │       └── sub-34_task-action_bold.nii.gz
# ├── sub-35
# │   ├── anat
# │   │   ├── sub-35_T1w.json
# │   │   └── sub-35_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-35_magnitude1.json
# │   │   ├── sub-35_magnitude1.nii.gz
# │   │   ├── sub-35_magnitude2.json
# │   │   ├── sub-35_magnitude2.nii.gz
# │   │   ├── sub-35_phasediff.json
# │   │   └── sub-35_phasediff.nii.gz
# │   └── func
# │       ├── sub-35_task-AON_run-01_bold.json
# │       ├── sub-35_task-AON_run-01_bold.nii.gz
# │       ├── sub-35_task-AON_run-02_bold.json
# │       ├── sub-35_task-AON_run-02_bold.nii.gz
# │       ├── sub-35_task-action_bold.json
# │       └── sub-35_task-action_bold.nii.gz
# ├── sub-36
# │   ├── anat
# │   │   ├── sub-36_T1w.json
# │   │   └── sub-36_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-36_magnitude1.json
# │   │   ├── sub-36_magnitude1.nii.gz
# │   │   ├── sub-36_magnitude2.json
# │   │   ├── sub-36_magnitude2.nii.gz
# │   │   ├── sub-36_phasediff.json
# │   │   └── sub-36_phasediff.nii.gz
# │   └── func
# │       ├── sub-36_task-AON_run-01_bold.json
# │       ├── sub-36_task-AON_run-01_bold.nii.gz
# │       ├── sub-36_task-AON_run-02_bold.json
# │       ├── sub-36_task-AON_run-02_bold.nii.gz
# │       ├── sub-36_task-action_bold.json
# │       └── sub-36_task-action_bold.nii.gz
# ├── sub-37
# │   ├── anat
# │   │   ├── sub-37_T1w.json
# │   │   └── sub-37_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-37_magnitude1.json
# │   │   ├── sub-37_magnitude1.nii.gz
# │   │   ├── sub-37_magnitude2.json
# │   │   ├── sub-37_magnitude2.nii.gz
# │   │   ├── sub-37_phasediff.json
# │   │   └── sub-37_phasediff.nii.gz
# │   └── func
# │       ├── sub-37_task-AON_run-01_bold.json
# │       ├── sub-37_task-AON_run-01_bold.nii.gz
# │       ├── sub-37_task-AON_run-02_bold.json
# │       ├── sub-37_task-AON_run-02_bold.nii.gz
# │       ├── sub-37_task-action_bold.json
# │       └── sub-37_task-action_bold.nii.gz
# ├── sub-38
# │   ├── anat
# │   │   ├── sub-38_T1w.json
# │   │   └── sub-38_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-38_magnitude1.json
# │   │   ├── sub-38_magnitude1.nii.gz
# │   │   ├── sub-38_magnitude2.json
# │   │   ├── sub-38_magnitude2.nii.gz
# │   │   ├── sub-38_phasediff.json
# │   │   └── sub-38_phasediff.nii.gz
# │   └── func
# │       ├── sub-38_task-AON_run-01_bold.json
# │       ├── sub-38_task-AON_run-01_bold.nii.gz
# │       ├── sub-38_task-AON_run-02_bold.json
# │       ├── sub-38_task-AON_run-02_bold.nii.gz
# │       ├── sub-38_task-action_bold.json
# │       └── sub-38_task-action_bold.nii.gz
# ├── sub-39
# │   ├── anat
# │   │   ├── sub-39_T1w.json
# │   │   └── sub-39_T1w.nii.gz
# │   ├── fmap
# │   │   ├── sub-39_magnitude1.json
# │   │   ├── sub-39_magnitude1.nii.gz
# │   │   ├── sub-39_magnitude2.json
# │   │   ├── sub-39_magnitude2.nii.gz
# │   │   ├── sub-39_phasediff.json
# │   │   └── sub-39_phasediff.nii.gz
# │   └── func
# │       ├── sub-39_task-AON_run-01_bold.json
# │       ├── sub-39_task-AON_run-01_bold.nii.gz
# │       ├── sub-39_task-AON_run-02_bold.json
# │       ├── sub-39_task-AON_run-02_bold.nii.gz
# │       ├── sub-39_task-action_bold.json
# │       └── sub-39_task-action_bold.nii.gz
# └── sub-40
#     ├── anat
#     │   ├── sub-40_T1w.json
#     │   └── sub-40_T1w.nii.gz
#     ├── fmap
#     │   ├── sub-40_magnitude1.json
#     │   ├── sub-40_magnitude1.nii.gz
#     │   ├── sub-40_magnitude2.json
#     │   ├── sub-40_magnitude2.nii.gz
#     │   ├── sub-40_phasediff.json
#     │   └── sub-40_phasediff.nii.gz
#     └── func
#         ├── sub-40_task-AON_run-01_bold.json
#         ├── sub-40_task-AON_run-01_bold.nii.gz
#         ├── sub-40_task-AON_run-02_bold.json
#         ├── sub-40_task-AON_run-02_bold.nii.gz
#         ├── sub-40_task-action_bold.json
#         └── sub-40_task-action_bold.nii.gz
#
# 160 directories, 560 files
